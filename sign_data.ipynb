# %% [markdown]
# <a href="https://colab.research.google.com/github/illhammm/Sign_preprocessing/blob/installer_and_load_dataset/sign_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyarrow
# !pip install pandas

# %%
import pandas as pd
import pyarrow.parquet as pq
from google.colab import files

# %% [markdown]
# **Загрузка файла .parquet на Google Colab**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2bf6ad65-0f34-4bea-830b-edf64f4711eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bf6ad65-0f34-4bea-830b-edf64f4711eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_name = list(uploaded.keys())[0]

# %% [markdown]
# Загрузка данных из файла .parquet

# %%
table = pq.read_table(file_name)
df = table.to_pandas()

# %%
try:
    # Попытка загрузки DataFrame из сохраненного файла
    df = pd.read_pickle('train-00000-of-00001-a16b0610cb895cd7.pkl')
except FileNotFoundError:
    # Если файл не найден, загрузим его из Google Colab
    uploaded = files.upload()
    file_name = list(uploaded.keys())[0]
    table = pq.read_table(file_name)
    df = table.to_pandas()
    # Сохранение DataFrame в файл
    df.to_pickle('train-00000-of-00001-a16b0610cb895cd7.pkl')
# Out:
#      <input type="file" id="files-0c3673d7-fcf6-413d-bb87-2145aa3a3b01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c3673d7-fcf6-413d-bb87-2145aa3a3b01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
